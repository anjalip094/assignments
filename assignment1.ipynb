# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Rreading dataset to python environment

# %%
data1=pd.read_excel(r'C:\Users\Lenovo\Desktop\data science\dataset\iris.xls')
data1.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Displaying the names of columns

# %%
data1.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Displaying the mean of each column

# %%
data1.mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for null values

# %%
data1.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# # Visualizations

# %%
#box plot

# %%
data2 = pd.DataFrame(data1, columns=['SL', 'SW', 'PL','PW'])
data2.plot.box(grid='True')
# Out:
# <AxesSubplot:>

# %%
#violin plot

# %%
SL=data1.SL
SW=data1.SW
PL=data1.PL
PW=data1.PW
fig, ax = plt.subplots()
ax.violinplot([SL, SW, PL,PW])
ax.set_title('Violin Plot')
plt.show()

# %%
#pairplot

# %%
data2 = data1[['SL','SW','PL','PW']]
sns.pairplot(data2)
